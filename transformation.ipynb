# %%
import os
import librosa
import pandas as pd
import numpy as np

# Fonction pour extraire les caractéristiques d'un fichier audio
def extract_features(audio_file):
    y, sr = librosa.load(audio_file)
    
    # Extraction des caractéristiques spécifiques
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rms = librosa.feature.rms(y=y)
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y=y)
    
    # Extraction de l'harmonie sans déballer en deux valeurs
    harmony = librosa.effects.harmonic(y)
    
    # Détection du tempo
    tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
    
    # Extraction des MFCC
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    
    # Calcul de la moyenne et de la variance des caractéristiques
    features = {
        'filename': audio_file,
        'length': len(y),
        'chroma_stft_mean': np.mean(chroma_stft),
        'chroma_stft_var': np.var(chroma_stft),
        'rms_mean': np.mean(rms),
        'rms_var': np.var(rms),
        'spectral_centroid_mean': np.mean(spectral_centroid),
        'spectral_centroid_var': np.var(spectral_centroid),
        'spectral_bandwidth_mean': np.mean(spectral_bandwidth),
        'spectral_bandwidth_var': np.var(spectral_bandwidth),
        'rolloff_mean': np.mean(rolloff),
        'rolloff_var': np.var(rolloff),
        'zero_crossing_rate_mean': np.mean(zero_crossing_rate),
        'zero_crossing_rate_var': np.var(zero_crossing_rate),
        'harmony_mean': np.mean(harmony),
        'harmony_var': np.var(harmony),
        'tempo': tempo,
    }
    
    # Calcul des MFCC
    for i in range(1, 21):  # MFCC1 à MFCC20
        features[f'mfcc{i}_mean'] = np.mean(mfcc[i-1])
        features[f'mfcc{i}_var'] = np.var(mfcc[i-1])
    
    return features

# Dossier contenant les fichiers audio .wav
audio_folder = './data/wav_songs'

# Liste des fichiers .wav dans le dossier
audio_files = [f for f in os.listdir(audio_folder) if f.endswith('.wav')]

# Liste pour stocker les caractéristiques extraites
all_features = []

# Traitement de chaque fichier audio
for audio_file in audio_files:
    audio_path = os.path.join(audio_folder, audio_file)
    
    # Extraction des caractéristiques
    features = extract_features(audio_path)
    
    # Ajouter les caractéristiques à la liste
    all_features.append(features)

# Conversion en DataFrame et sauvegarde au format CSV
df = pd.DataFrame(all_features)
df.to_csv('audio_features_all.csv', index=False)

print("Features extracted for all files and saved to audio_features_all.csv.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 69
#      66 audio_path = os.path.join(audio_folder, audio_file)
#      68 # Extraction des caractéristiques
# ---> 69 features = extract_features(audio_path)
#      71 # Ajouter les caractéristiques à la liste
#      72 all_features.append(features)
#
# Cell In[4], line 19, in extract_features(audio_file)
#      16 zero_crossing_rate = librosa.feature.zero_crossing_rate(y=y)
#      18 # Extraction de l'harmonie sans déballer en deux valeurs
# ---> 19 harmony = librosa.effects.harmonic(y)
#      21 # Détection du tempo
#      22 tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
#
# File c:\Users\pc\Documents\asri_non_structured\venv\Lib\site-packages\librosa\effects.py:238, in harmonic(y, kernel_size, power, mask, margin, n_fft, hop_length, win_length, window, center, pad_mode)
#     228 stft = core.stft(
#     229     y,
#     230     n_fft=n_fft,
#    (...)    234     pad_mode=pad_mode,
#     235 )
#     237 # Remove percussives
# --> 238 stft_harm = decompose.hpss(
#     239     stft, kernel_size=kernel_size, power=power, mask=mask, margin=margin
#     240 )[0]
#     242 # Invert the STFTs
#     243 y_harm = core.istft(
#     244     stft_harm,
#     245     dtype=y.dtype,
#    (...)    250     length=y.shape[-1],
#     251 )
#
# File c:\Users\pc\Documents\asri_non_structured\venv\Lib\site-packages\librosa\decompose.py:393, in hpss(S, kernel_size, power, mask, margin)
#     390 harm[:] = median_filter(S, size=harm_shape, mode="reflect")
#     392 perc = np.empty_like(S)
# --> 393 perc[:] = median_filter(S, size=perc_shape, mode="reflect")
#     395 split_zeros = margin_harm == 1 and margin_perc == 1
#     397 mask_harm = util.softmask(
#     398     harm, perc * margin_harm, power=power, split_zeros=split_zeros
#     399 )
#
# File c:\Users\pc\Documents\asri_non_structured\venv\Lib\site-packages\scipy\ndimage\_filters.py:1684, in median_filter(input, size, footprint, output, mode, cval, origin, axes)
#    1634 @_ni_docstrings.docfiller
#    1635 def median_filter(input, size=None, footprint=None, output=None,
#    1636                   mode="reflect", cval=0.0, origin=0, *, axes=None):
#    1637     """
#    1638     Calculate a multidimensional median filter.
#    1639
#    (...)   1682     >>> plt.show()
#    1683     """
# -> 1684     return _rank_filter(input, 0, size, footprint, output, mode, cval,
#    1685                         origin, 'median', axes=axes)
#
# File c:\Users\pc\Documents\asri_non_structured\venv\Lib\site-packages\scipy\ndimage\_filters.py:1580, in _rank_filter(input, rank, size, footprint, output, mode, cval, origin, operation, axes)
#    1578         np.copyto(output, x_out, casting='unsafe')
#    1579 else:
# -> 1580     _nd_image.rank_filter(input, rank, footprint, output, mode, cval, origins)
#    1581 if temp_needed:
#    1582     temp[...] = output
#
# KeyboardInterrupt:

# %%
import os
import ffmpeg
import librosa
import pandas as pd
import numpy as np

# Fonction pour extraire les caractéristiques d'un fichier audio
def extract_features(audio_file):
    y, sr = librosa.load(audio_file)
    
    # Extraction des caractéristiques spécifiques
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rms = librosa.feature.rms(y=y)
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y=y)
    
    # Extraction de l'harmonie sans déballer en deux valeurs
    harmony = librosa.effects.harmonic(y)
    
    # Détection du tempo
    tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
    
    # Extraction des MFCC
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    
    # Calcul de la moyenne et de la variance des caractéristiques
    features = {
        'filename': audio_file,
        'length': len(y),
        'chroma_stft_mean': np.mean(chroma_stft),
        'chroma_stft_var': np.var(chroma_stft),
        'rms_mean': np.mean(rms),
        'rms_var': np.var(rms),
        'spectral_centroid_mean': np.mean(spectral_centroid),
        'spectral_centroid_var': np.var(spectral_centroid),
        'spectral_bandwidth_mean': np.mean(spectral_bandwidth),
        'spectral_bandwidth_var': np.var(spectral_bandwidth),
        'rolloff_mean': np.mean(rolloff),
        'rolloff_var': np.var(rolloff),
        'zero_crossing_rate_mean': np.mean(zero_crossing_rate),
        'zero_crossing_rate_var': np.var(zero_crossing_rate),
        'harmony_mean': np.mean(harmony),
        'harmony_var': np.var(harmony),
        'tempo': tempo,
    }
    
    # Calcul des MFCC
    for i in range(1, 21):  # MFCC1 à MFCC20
        features[f'mfcc{i}_mean'] = np.mean(mfcc[i-1])
        features[f'mfcc{i}_var'] = np.var(mfcc[i-1])
    
    return features

# Fonction pour extraire l'audio à partir d'une vidéo
def extract_audio_from_video(video_file, output_audio_file):
    try:
        # Utilisation de ffmpeg pour extraire l'audio
        ffmpeg.input(video_file).output(output_audio_file).run()
        print(f"Audio extrait et sauvegardé sous {output_audio_file}")
    except ffmpeg.Error as e:
        print(f"Erreur lors de l'extraction de l'audio: {e}")

# Dossier contenant les vidéos
video_folder = r'C:\Users\pc\Documents\asri_non_structured\data\top_songs_database'

# Liste des fichiers vidéo dans le dossier
video_files = [f for f in os.listdir(video_folder) if f.endswith('.mp4')]  # Modifier l'extension si nécessaire

# Liste pour stocker les caractéristiques extraites
all_features = []

# Traitement de chaque fichier vidéo
for video_file in video_files:
    video_path = os.path.join(video_folder, video_file)
    
    # Nom du fichier audio de sortie (wav)
    audio_file = os.path.splitext(video_file)[0] + '.wav'
    audio_path = os.path.join(video_folder, audio_file)
    
    # Extraire l'audio du fichier vidéo
    extract_audio_from_video(video_path, audio_path)
    
    # Extraire les caractéristiques de l'audio
    features = extract_features(audio_path)
    
    # Ajouter les caractéristiques à la liste
    all_features.append(features)

# Sauvegarder les caractéristiques dans un fichier CSV
df = pd.DataFrame(all_features)
df.to_csv('audio_features.csv', index=False)

print("Caractéristiques extraites et sauvegardées dans audio_features.csv.")
# Out:
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\001 - ROSÉ & Bruno Mars - APT. (Official Music Video).wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\002 - MANIAC (Official Video)： YO YO HONEY SINGH ｜ ESHA GUPTA ｜ GLORY ｜ BHUSHAN KUMAR.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\003 - Lady Gaga, Bruno Mars - Die With A Smile (Official Music Video).wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\004 - Aaj Ki Raat -Full Song ｜Stree 2｜Tamannaah Bhatia｜Rajkummar Rao｜Sachin-Jigar｜Madhubanti｜Divya｜Amitabh.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\005 - Sanam Teri Kasam, (Lyrical Video) - Harshvardhan, Mawra ｜ Ankit Tiwari ｜ Palak M ｜ Himesh Reshammiya.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\006 - Uyi Amma - Azaad ｜ Aaman D, Rasha Thadani｜ Madhubanti Bagchi,Amit Trivedi,Amitabh｜ Bosco｜ Abhishek K.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\007 - JENNIE, Doechii - ExtraL (Official Video).wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\008 - W&W - OIIA OIIA (Spinning Cat).wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\009 - RANU BOMBAI KI RANU FULL SONG ｜ RAMU RATHOD ｜ LIKHITHA ｜ KALYAN KEYS ｜ PRABHA ｜ RATHOD TUNES.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\010 - KAROL G - Si Antes Te Hubiera Conocido ｜ Coke Studio.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\011 - Billie Eilish - BIRDS OF A FEATHER (Official Music Video).wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\012 - तुनक तुनक  बुंदेली सॉन्ग!!Tunak tunak song ! Sun bhauji ki bhain song !Roshan mahoba !Anjli & Sapna.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\013 - Full Video： Godari Gattu - Sankranthiki Vasthunam ｜ Venkatesh,Aishwarya ｜ Anil Ravipudi ｜ Bheems C.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\014 - F.HERO Ft. ก้านตอง ทุ่งเงิน x SARAN - กุหลาบ (KULARB) [OFFICIAL VISUALIZER].wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\015 - Kendrick Lamar - Not Like Us.wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database\016 - Victor Valverde x JR Torres - El Mayor de Los Ranas (Video Oficial).wav
# Audio extrait et sauvegardé sous C:\Users\pc\Documents\asri_non_structured\data\top_songs_database